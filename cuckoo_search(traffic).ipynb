# %% [markdown]
# **Cukoo Search Alogorithm for traffic signal optimization**

# %%
import numpy as np
from scipy.special import gamma

def fitness_function(x):

    waiting_times = np.array([10 + (x[i] ** 2) / 100 for i in range(len(x))])
    total_waiting_time = np.sum(waiting_times)
    return total_waiting_time

def levy_flight(dim, beta=1.5):
    """
    Generates a step using Levy flight distribution for global exploration.
    """
    sigma_u = np.power((gamma(1 + beta) * np.sin(np.pi * beta / 2) /
                        gamma((1 + beta) / 2) * beta * (2 ** (beta - 1))), 1 / beta)
    u = np.random.normal(0, sigma_u, dim)
    v = np.random.normal(0, 1, dim)
    step = u / np.power(np.abs(v), 1 / beta)
    return step


def cuckoo_search(dim, bounds, num_nests, max_iter, p_a=0.25, Lambda=1.5):
    nests = np.random.uniform(bounds[0], bounds[1], (num_nests, dim))


    fitness = np.array([fitness_function(nest) for nest in nests])


    best_idx = np.argmin(fitness)
    best_nest = nests[best_idx]
    best_fitness = fitness[best_idx]

    for iter in range(max_iter):
        new_nests = np.copy(nests)
        for i in range(num_nests):
            step = levy_flight(dim, Lambda)
            new_nests[i] = nests[i] + step


            new_nests[i] = np.clip(new_nests[i], bounds[0], bounds[1])


        new_fitness = np.array([fitness_function(nest) for nest in new_nests])


        for i in range(num_nests):
            if new_fitness[i] < fitness[i]:
                nests[i] = new_nests[i]
                fitness[i] = new_fitness[i]


        if np.random.rand() < p_a:
            random_idx = np.random.randint(num_nests)
            nests[random_idx] = np.random.uniform(bounds[0], bounds[1], dim)
            fitness[random_idx] = fitness_function(nests[random_idx])


        current_best_idx = np.argmin(fitness)
        current_best_fitness = fitness[current_best_idx]

        if current_best_fitness < best_fitness:
            best_fitness = current_best_fitness
            best_nest = nests[current_best_idx]

        print(f"Iteration {iter + 1}/{max_iter}, Best Fitness: {best_fitness}")

    return best_nest, best_fitness


dim = 3
bounds = [10, 120]
num_nests = 20
max_iter = 100

best_solution, best_value = cuckoo_search(dim, bounds, num_nests, max_iter)

print("\nBest Solution (Green Light Timings):", best_solution)
print("Best Fitness Value (Total Waiting Time):", best_value)
# Out:
# Iteration 1/100, Best Fitness: 50.00578003998493
# Iteration 2/100, Best Fitness: 50.00578003998493
# Iteration 3/100, Best Fitness: 49.91710010056269
# Iteration 4/100, Best Fitness: 47.49916502449787
# Iteration 5/100, Best Fitness: 47.49916502449787
# Iteration 6/100, Best Fitness: 47.49916502449787
# Iteration 7/100, Best Fitness: 47.49916502449787
# Iteration 8/100, Best Fitness: 47.49916502449787
# Iteration 9/100, Best Fitness: 47.409342424871326
# Iteration 10/100, Best Fitness: 47.24693291266968
# Iteration 11/100, Best Fitness: 46.651533138440016
# Iteration 12/100, Best Fitness: 39.05988566256537
# Iteration 13/100, Best Fitness: 39.05988566256537
# Iteration 14/100, Best Fitness: 38.327727731473445
# Iteration 15/100, Best Fitness: 37.10008774443265
# Iteration 16/100, Best Fitness: 37.10008774443265
# Iteration 17/100, Best Fitness: 37.10008774443265
# Iteration 18/100, Best Fitness: 37.10008774443265
# Iteration 19/100, Best Fitness: 36.82577731191278
# Iteration 20/100, Best Fitness: 35.985615564906496
# Iteration 21/100, Best Fitness: 35.985615564906496
# Iteration 22/100, Best Fitness: 35.18599290973988
# Iteration 23/100, Best Fitness: 33.43522054259725
# Iteration 24/100, Best Fitness: 33.43522054259725
# Iteration 25/100, Best Fitness: 33.43522054259725
# Iteration 26/100, Best Fitness: 33.43522054259725
# Iteration 27/100, Best Fitness: 33.18475913402465
# Iteration 28/100, Best Fitness: 33.18475913402465
# Iteration 29/100, Best Fitness: 33.18475913402465
# Iteration 30/100, Best Fitness: 33.18475913402465
# Iteration 31/100, Best Fitness: 33.0
# Iteration 32/100, Best Fitness: 33.0
# Iteration 33/100, Best Fitness: 33.0
# Iteration 34/100, Best Fitness: 33.0
# Iteration 35/100, Best Fitness: 33.0
# Iteration 36/100, Best Fitness: 33.0
# Iteration 37/100, Best Fitness: 33.0
# Iteration 38/100, Best Fitness: 33.0
# Iteration 39/100, Best Fitness: 33.0
# Iteration 40/100, Best Fitness: 33.0
# Iteration 41/100, Best Fitness: 33.0
# Iteration 42/100, Best Fitness: 33.0
# Iteration 43/100, Best Fitness: 33.0
# Iteration 44/100, Best Fitness: 33.0
# Iteration 45/100, Best Fitness: 33.0
# Iteration 46/100, Best Fitness: 33.0
# Iteration 47/100, Best Fitness: 33.0
# Iteration 48/100, Best Fitness: 33.0
# Iteration 49/100, Best Fitness: 33.0
# Iteration 50/100, Best Fitness: 33.0
# Iteration 51/100, Best Fitness: 33.0
# Iteration 52/100, Best Fitness: 33.0
# Iteration 53/100, Best Fitness: 33.0
# Iteration 54/100, Best Fitness: 33.0
# Iteration 55/100, Best Fitness: 33.0
# Iteration 56/100, Best Fitness: 33.0
# Iteration 57/100, Best Fitness: 33.0
# Iteration 58/100, Best Fitness: 33.0
# Iteration 59/100, Best Fitness: 33.0
# Iteration 60/100, Best Fitness: 33.0
# Iteration 61/100, Best Fitness: 33.0
# Iteration 62/100, Best Fitness: 33.0
# Iteration 63/100, Best Fitness: 33.0
# Iteration 64/100, Best Fitness: 33.0
# Iteration 65/100, Best Fitness: 33.0
# Iteration 66/100, Best Fitness: 33.0
# Iteration 67/100, Best Fitness: 33.0
# Iteration 68/100, Best Fitness: 33.0
# Iteration 69/100, Best Fitness: 33.0
# Iteration 70/100, Best Fitness: 33.0
# Iteration 71/100, Best Fitness: 33.0
# Iteration 72/100, Best Fitness: 33.0
# Iteration 73/100, Best Fitness: 33.0
# Iteration 74/100, Best Fitness: 33.0
# Iteration 75/100, Best Fitness: 33.0
# Iteration 76/100, Best Fitness: 33.0
# Iteration 77/100, Best Fitness: 33.0
# Iteration 78/100, Best Fitness: 33.0
# Iteration 79/100, Best Fitness: 33.0
# Iteration 80/100, Best Fitness: 33.0
# Iteration 81/100, Best Fitness: 33.0
# Iteration 82/100, Best Fitness: 33.0
# Iteration 83/100, Best Fitness: 33.0
# Iteration 84/100, Best Fitness: 33.0
# Iteration 85/100, Best Fitness: 33.0
# Iteration 86/100, Best Fitness: 33.0
# Iteration 87/100, Best Fitness: 33.0
# Iteration 88/100, Best Fitness: 33.0
# Iteration 89/100, Best Fitness: 33.0
# Iteration 90/100, Best Fitness: 33.0
# Iteration 91/100, Best Fitness: 33.0
# Iteration 92/100, Best Fitness: 33.0
# Iteration 93/100, Best Fitness: 33.0
# Iteration 94/100, Best Fitness: 33.0
# Iteration 95/100, Best Fitness: 33.0
# Iteration 96/100, Best Fitness: 33.0
# Iteration 97/100, Best Fitness: 33.0
# Iteration 98/100, Best Fitness: 33.0
# Iteration 99/100, Best Fitness: 33.0
# Iteration 100/100, Best Fitness: 33.0
#
# Best Solution (Green Light Timings): [10.45172818 10.         10.        ]
# Best Fitness Value (Total Waiting Time): 33.0
